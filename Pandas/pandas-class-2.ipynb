# %%
class Test:
    def __init__(self):
        self.value = 42

    def __getattribute__(self, name):
        print(f"Getting {name}")
        return super().__getattribute__(name)

obj = Test()
print(obj.value)
# Out:
# Getting value
# 42

# %%
class MyDescriptor:
    def __set__(self, instance, value):
        print(f"Setting value to: {value}")
        instance._value = value

class MyClass:
    attr = MyDescriptor()

obj = MyClass()
obj.attr = 10  # Triggers __set__, prints "Setting value to: 10"
# Out:
# Setting value to: 10

# %%
lst = [1,2]
lst*2
# Out:
# [1, 2, 1, 2]

# %%
import pandas as pd
df = pd.read_csv("insurance.csv")

# %%
data = pd.read_csv("insurance.csv")

# %%
data['Tax-amount'] = data.apply(lambda row : row['charges']*.15 if (row['sex']=='male') & (row['smoker']=='yes')
                    else row['charges']*.10 if (row['sex']=='male') & (row['smoker']=='no')
                    else row['charges']*.20 if (row['sex']=='female') & (row['smoker']=='yes')
                    else row['charges']*.5 if (row['sex']=='female') & (row['smoker']=='no')
                    else 0 , axis=1)

# %%
data['Net-amount'] = data['charges']-data['Tax-amount']

# %%
d
# Out:
# 0       3376.984800
# 1        172.555230
# 2        444.946200
# 3       2198.447061
# 4        386.685520
#            ...
# 1333    1060.054830
# 1334    1102.990400
# 1335     814.916750
# 1336    1003.972500
# 1337    5828.272060
# Name: Tax-amount, Length: 1338, dtype: float64

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#        Tax-amount    Net-amount
# 0     3376.984800  13507.939200
# 1      172.555230   1552.997070
# 2      444.946200   4004.515800
# ...

# %%
std = pd.read_csv("student.csv")

# %%
sum(std['']
# Out:
#      Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 0     Julia Smith        R001            46           49            66
# 1   Hannah Taylor        R002            48           63            91
# 2   George Wilson        R003           100           76            88
# 3     Ethan Jones        R004            57           97            75
# 4   Charlie Smith        R005            63           66            69
# ..            ...         ...           ...          ...           ...
# 95   Diana Miller        R096            54           71            56
# 96    Diana Davis        R097            90           64            64
# 97      Bob Moore        R098            62           79            56
# 98   Hannah Brown        R099            68           90            81
# 99   George Davis        R100            66           84            83
#
#     Stats Marks  ML Marks
# 0            92        65
# 1            85        44
# 2            96        48
# ...

# %%
std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  100 non-null    object
#  1   Roll Number   100 non-null    object
#  2   Python Marks  100 non-null    int64
#  3   Numpy Marks   100 non-null    int64
#  4   Pandas Marks  100 non-null    int64
#  5   Stats Marks   100 non-null    int64
#  6   ML Marks      100 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 5.6+ KB

# %%
std['Obtained-Marks'] = std.apply(lambda col: col['Python Marks'] + col['Numpy Marks']+col['Pandas Marks']+ col['Stats Marks']+ col['ML Marks'],axis=1)

# %%
std['%Percentage'] = (std['Total']/500)*100

# %%
std.sample(40)
# Out:
#        Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 51      Bob Johnson        R052            73           76            45
# 5      Julia Miller        R006            48           94            93
# 4     Charlie Smith        R005            63           66            69
# 28       Ian Taylor        R029            41           87            58
# 30  Hannah Williams        R031            46           41            60
# 59    Charlie Brown        R060            47           99            40
# 50      Alice Davis        R051            41           55            88
# 36      Diana Jones        R037            53           91            41
# 77    Hannah Wilson        R078            64           88            44
# 64      Fiona Moore        R065           100           73            49
# 7         Ian Smith        R008            84           56            67
# 58    George Taylor        R059            81           82            62
# ...

# %%
a =  std['Python Marks'] + std['Numpy Marks']+std['Pandas Marks']+ std['Stats Marks']+ std['ML Marks']

# %%
std['Obtain']= a

# %%
del std['Obtain']

# %%
std["Grade"] = std['%Percentage'].apply(lambda x: "A+" if x>= 90 
                     else "A" if x>=80
                     else "B" if x>=70
                     else "C" if x>=60
                     else "D" if x>=50
                     else "F")

# %%
std
# Out:
#      Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 0     Julia Smith        R001            46           49            66
# 1   Hannah Taylor        R002            48           63            91
# 2   George Wilson        R003           100           76            88
# 3     Ethan Jones        R004            57           97            75
# 4   Charlie Smith        R005            63           66            69
# ..            ...         ...           ...          ...           ...
# 95   Diana Miller        R096            54           71            56
# 96    Diana Davis        R097            90           64            64
# 97      Bob Moore        R098            62           79            56
# 98   Hannah Brown        R099            68           90            81
# 99   George Davis        R100            66           84            83
#
#     Stats Marks  ML Marks  %Percentage  Obtained-Marks Grade
# ...

# %%
df.set_index("age",inplace=True)

# %%
df.reset_index(inplace=True)

# %%
std.iloc[4:8,0:10]
# Out:
#     Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 4  Charlie Smith        R005            63           66            69
# 5   Julia Miller        R006            48           94            93
# 6   Julia Miller        R007            40           97            75
# 7      Ian Smith        R008            84           56            67
#
#    Stats Marks  ML Marks  %Percentage  Obtained-Marks Grade
# 4           76        58         66.4             332     C
# 5           57        72         72.8             364     B
# 6           73        44         65.8             329     C
# 7           40        99         69.2             346     C

# %%
std.loc[4:8,'Roll Number':'Grade']
# Out:
#   Roll Number  Python Marks  Numpy Marks  Pandas Marks  Stats Marks  ML Marks  \
# 4        R005            63           66            69           76        58
# 5        R006            48           94            93           57        72
# 6        R007            40           97            75           73        44
# 7        R008            84           56            67           40        99
# 8        R009            91           84            81           67        85
#
#    %Percentage  Obtained-Marks Grade
# 4         66.4             332     C
# 5         72.8             364     B
# 6         65.8             329     C
# 7         69.2             346     C
# 8         81.6             408     A

# %%
std.head()
# Out:
#     Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 0    Julia Smith        R001            46           49            66
# 1  Hannah Taylor        R002            48           63            91
# 2  George Wilson        R003           100           76            88
# 3    Ethan Jones        R004            57           97            75
# 4  Charlie Smith        R005            63           66            69
#
#    Stats Marks  ML Marks  %Percentage  Obtained-Marks Grade
# 0           92        65         63.6             318     C
# 1           85        44         66.2             331     C
# 2           96        48         81.6             408     A
# 3           89        66         76.8             384     B
# 4           76        58         66.4             332     C

# %%
df[df['sex']=='male']
# Out:
#       age   sex     bmi  children smoker     region      charges   Tax-amount  \
# 1      18  male  33.770         1     no  southeast   1725.55230   172.555230
# 2      28  male  33.000         3     no  southeast   4449.46200   444.946200
# 3      33  male  22.705         0     no  northwest  21984.47061  2198.447061
# 4      32  male  28.880         0     no  northwest   3866.85520   386.685520
# 8      37  male  29.830         2     no  northeast   6406.41070   640.641070
# ...   ...   ...     ...       ...    ...        ...          ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265   423.989265
# 1325   61  male  33.535         0     no  northeast  13143.33665  1314.333665
# 1327   51  male  30.030         1     no  southeast   9377.90470   937.790470
# 1329   52  male  38.600         2     no  southwest  10325.20600  1032.520600
# 1333   50  male  30.970         3     no  northwest  10600.54830  1060.054830
#
#       Total
# 1     283.0
# ...

# %%
emp = pd.read_excel("emp.xlsx")

# %%
emp
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
emp[(emp['Department']=='Account') & (emp['Age']>30) &( emp['Salary']>=100000)]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 11      12    3214  Accountant    Account  49.0  123000.0

# %%
python_grade = std[(std['Python Marks']>=50) &( std['Grade']=='B')]

# %%
python_grade.count()
# Out:
# Student Name      36
# Roll Number       36
# Python Marks      36
# Numpy Marks       36
# Pandas Marks      36
# Stats Marks       36
# ML Marks          36
# %Percentage       36
# Obtained-Marks    36
# Grade             36
# dtype: int64

# %%
python_grade
# Out:
#         Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 3        Ethan Jones        R004            57           97            75
# 11      Fiona Taylor        R012            55           66            54
# 12       Fiona Brown        R013            82           69            71
# 16     Charlie Davis        R017            96           68            65
# 26         Bob Smith        R027            70          100            61
# 33    George Johnson        R034            55           65            81
# 36       Diana Jones        R037            53           91            41
# 38   Hannah Williams        R039            61           82            96
# 40      Bob Williams        R041            86           78            63
# 44      Fiona Miller        R045            81           81            86
# 46      Hannah Moore        R047            72           93            51
# 49         Bob Jones        R050            64           89            76
# ...

# %%
std[(std['Student Name']>) &( std['Grade']=='B')]

# %%
if 'john' in std['Student Name']:
    print(True)

# %%
std['Student Name'].contains("Jones")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14244\1264306157.py in ?()
# ----> 1 std['Student Name'].contains("Jones")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'contains'

# %%
std[std['Student Name'].str.contains("Jones")][['Student Name','Grade']]
# Out:
#      Student Name Grade
# 3     Ethan Jones     B
# 36    Diana Jones     B
# 41    Alice Jones     A
# 49      Bob Jones     B
# 52    Julia Jones     B
# 65      Bob Jones     C
# 68    Diana Jones     B
# 70    Fiona Jones     B
# 80  Charlie Jones     B
# 85    Diana Jones     B

# %%
std[std['Student Name'].str.contains("Jones")][[']]

# %%
mark = std[std['Pandas Marks'] + std['Stats Marks'] >=56][['Python Marks','Stats Marks']]

# %%
mark.count()
# Out:
# Python Marks    100
# Stats Marks     100
# dtype: int64

# %%
mark
# Out:
#     Python Marks  Stats Marks
# 0             46           92
# 1             48           85
# 2            100           96
# 3             57           89
# 4             63           76
# ..           ...          ...
# 95            54           43
# 96            90           65
# 97            62          100
# 98            68           68
# 99            66           53
#
# [100 rows x 2 columns]

# %%
std.Grade.unique()
# Out:
# array(['C', 'A', 'B', 'F', 'D'], dtype=object)

# %%
std.Grade.value_counts()
# Out:
# Grade
# C    41
# B    41
# A    13
# D     4
# F     1
# Name: count, dtype: int64

# %%
std[std['Grade'] == 'F']
# Out:
#    Student Name Roll Number  Python Marks  Numpy Marks  Pandas Marks  \
# 29    Bob Davis        R030            49           52            43
#
#     Stats Marks  ML Marks  %Percentage  Obtained-Marks Grade
# 29           40        42         45.2             226     F
